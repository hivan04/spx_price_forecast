# %%
from pmdarima.arima import auto_arima

# %%
import yfinance as yf
import numpy as np

# %%
raw_data = yf.download(tickers="^GSPC ^FTSE ^N225 ^GDAXI", start="1994-01-07", end="2018-01-29", 
                       interval="1d", group_by='ticker', auto_adjust=True, threads=True)

df_comp = raw_data.copy()
df_comp['spx'] = df_comp['^GSPC'].Close[:]
df_comp['dax'] = df_comp['^GDAXI'].Close[:]
df_comp['ftse'] = df_comp['^FTSE'].Close[:]
df_comp['nikkei'] = df_comp['^N225'].Close[:]

df_comp = df_comp.iloc[1:]
del df_comp['^N225']
del df_comp['^GSPC']
del df_comp['^GDAXI']
del df_comp['^FTSE']
df_comp=df_comp.asfreq('b')
df_comp=df_comp.fillna(method='ffill')

df_comp['ret_spx'] = df_comp.spx.pct_change(1)*100
df_comp['ret_ftse'] = df_comp.ftse.pct_change(1)*100
df_comp['ret_dax'] = df_comp.dax.pct_change(1)*100
df_comp['ret_nikkei'] = df_comp.nikkei.pct_change(1)*100
# Out:
# [*********************100%***********************]  4 of 4 completed

# %%
model_auto = auto_arima(df_comp.ret_ftse[1:])
# Out:
# /Users/ivan/Documents/Data Science Projects/arimatut/ARIMAtut/tutenv/lib/python3.9/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/ivan/Documents/Data Science Projects/arimatut/ARIMAtut/tutenv/lib/python3.9/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/ivan/Documents/Data Science Projects/arimatut/ARIMAtut/tutenv/lib/python3.9/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/ivan/Documents/Data Science Projects/arimatut/ARIMAtut/tutenv/lib/python3.9/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/ivan/Documents/Data Science Projects/arimatut/ARIMAtut/tutenv/lib/python3.9/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/ivan/Documents/Data Science Projects/arimatut/ARIMAtut/tutenv/lib/python3.9/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/ivan/Documents/Data Science Projects/arimatut/ARIMAtut/tutenv/lib/python3.9/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/ivan/Documents/Data Science Projects/arimatut/ARIMAtut/tutenv/lib/python3.9/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/ivan/Documents/Data Science Projects/arimatut/ARIMAtut/tutenv/lib/python3.9/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/ivan/Documents/Data Science Projects/arimatut/ARIMAtut/tutenv/lib/python3.9/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/ivan/Documents/Data Science Projects/arimatut/ARIMAtut/tutenv/lib/python3.9/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/ivan/Documents/Data Science Projects/arimatut/ARIMAtut/tutenv/lib/python3.9/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/ivan/Documents/Data Science Projects/arimatut/ARIMAtut/tutenv/lib/python3.9/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/ivan/Documents/Data Science Projects/arimatut/ARIMAtut/tutenv/lib/python3.9/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/ivan/Documents/Data Science Projects/arimatut/ARIMAtut/tutenv/lib/python3.9/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/ivan/Documents/Data Science Projects/arimatut/ARIMAtut/tutenv/lib/python3.9/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/ivan/Documents/Data Science Projects/arimatut/ARIMAtut/tutenv/lib/python3.9/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/ivan/Documents/Data Science Projects/arimatut/ARIMAtut/tutenv/lib/python3.9/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/ivan/Documents/Data Science Projects/arimatut/ARIMAtut/tutenv/lib/python3.9/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/ivan/Documents/Data Science Projects/arimatut/ARIMAtut/tutenv/lib/python3.9/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/ivan/Documents/Data Science Projects/arimatut/ARIMAtut/tutenv/lib/python3.9/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/ivan/Documents/Data Science Projects/arimatut/ARIMAtut/tutenv/lib/python3.9/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/ivan/Documents/Data Science Projects/arimatut/ARIMAtut/tutenv/lib/python3.9/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/ivan/Documents/Data Science Projects/arimatut/ARIMAtut/tutenv/lib/python3.9/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/ivan/Documents/Data Science Projects/arimatut/ARIMAtut/tutenv/lib/python3.9/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/ivan/Documents/Data Science Projects/arimatut/ARIMAtut/tutenv/lib/python3.9/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/ivan/Documents/Data Science Projects/arimatut/ARIMAtut/tutenv/lib/python3.9/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/ivan/Documents/Data Science Projects/arimatut/ARIMAtut/tutenv/lib/python3.9/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/ivan/Documents/Data Science Projects/arimatut/ARIMAtut/tutenv/lib/python3.9/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(

# %%
model_auto
# Out:
# ARIMA(order=(4, 0, 5), scoring_args={}, suppress_warnings=True)

# %%
print(model_auto.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 6274
# Model:               SARIMAX(4, 0, 5)   Log Likelihood               -9551.974
# Date:                Tue, 25 Feb 2025   AIC                          19125.949
# Time:                        21:13:48   BIC                          19200.135
# Sample:                    01-11-1994   HQIC                         19151.653
#                          - 01-26-2018
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.0271      0.018      1.488      0.137      -0.009       0.063
# ar.L1          0.0794      0.081      0.984      0.325      -0.079       0.238
# ar.L2         -0.5808      0.079     -7.306      0.000      -0.737      -0.425
# ar.L3         -0.1280      0.072     -1.776      0.076      -0.269       0.013
# ar.L4          0.2578      0.076      3.407      0.001       0.109       0.406
# ma.L1         -0.0989      0.081     -1.226      0.220      -0.257       0.059
# ma.L2          0.5345      0.081      6.605      0.000       0.376       0.693
# ma.L3          0.0502      0.071      0.710      0.478      -0.088       0.189
# ma.L4         -0.2566      0.076     -3.397      0.001      -0.405      -0.109
# ma.L5         -0.0895      0.009    -10.445      0.000      -0.106      -0.073
# sigma2         1.2309      0.012    103.955      0.000       1.208       1.254
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):              8788.11
# Prob(Q):                              0.97   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.87   Skew:                            -0.19
# Prob(H) (two-sided):                  0.00   Kurtosis:                         8.79
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
model_auto_spx = auto_arima(df_comp.ret_spx[1:])
# Out:
# /Users/ivan/Documents/Data Science Projects/arimatut/ARIMAtut/tutenv/lib/python3.9/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/ivan/Documents/Data Science Projects/arimatut/ARIMAtut/tutenv/lib/python3.9/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/ivan/Documents/Data Science Projects/arimatut/ARIMAtut/tutenv/lib/python3.9/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/ivan/Documents/Data Science Projects/arimatut/ARIMAtut/tutenv/lib/python3.9/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/ivan/Documents/Data Science Projects/arimatut/ARIMAtut/tutenv/lib/python3.9/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/ivan/Documents/Data Science Projects/arimatut/ARIMAtut/tutenv/lib/python3.9/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/ivan/Documents/Data Science Projects/arimatut/ARIMAtut/tutenv/lib/python3.9/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/ivan/Documents/Data Science Projects/arimatut/ARIMAtut/tutenv/lib/python3.9/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/ivan/Documents/Data Science Projects/arimatut/ARIMAtut/tutenv/lib/python3.9/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/ivan/Documents/Data Science Projects/arimatut/ARIMAtut/tutenv/lib/python3.9/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/ivan/Documents/Data Science Projects/arimatut/ARIMAtut/tutenv/lib/python3.9/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/ivan/Documents/Data Science Projects/arimatut/ARIMAtut/tutenv/lib/python3.9/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/ivan/Documents/Data Science Projects/arimatut/ARIMAtut/tutenv/lib/python3.9/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/ivan/Documents/Data Science Projects/arimatut/ARIMAtut/tutenv/lib/python3.9/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/ivan/Documents/Data Science Projects/arimatut/ARIMAtut/tutenv/lib/python3.9/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/ivan/Documents/Data Science Projects/arimatut/ARIMAtut/tutenv/lib/python3.9/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(

# %%
model_auto_spx
# Out:
# ARIMA(order=(1, 0, 1), scoring_args={}, suppress_warnings=True)

# %%
print(model_auto_spx.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 6274
# Model:               SARIMAX(1, 0, 1)   Log Likelihood               -9655.658
# Date:                Tue, 25 Feb 2025   AIC                          19319.315
# Time:                        21:16:12   BIC                          19346.292
# Sample:                    01-11-1994   HQIC                         19328.662
#                          - 01-26-2018
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.0127      0.005      2.479      0.013       0.003       0.023
# ar.L1          0.6371      0.046     13.955      0.000       0.548       0.727
# ma.L1         -0.7032      0.041    -17.036      0.000      -0.784      -0.622
# sigma2         1.2714      0.010    125.918      0.000       1.252       1.291
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.19   Jarque-Bera (JB):             20280.33
# Prob(Q):                              0.66   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.74   Skew:                            -0.27
# Prob(H) (two-sided):                  0.00   Kurtosis:                        11.79
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
